# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
import numpy as np
from sklearn.cluster import MeanShift, estimate_bandwidth
import matplotlib.pyplot as plt
from itertools import cycle
from PIL import Image

from pylab import rcParams
rcParams['figure.figsize'] = 30, 15

# %%
image = Image.open('Jerry_Mouse.png')
image = np.array(image)
 
#Need to convert image into feature array based
#on rgb intensities
flat_image=np.reshape(image, [-1, 3])
print(image.shape)

#Estimate bandwidth
bandwidth = estimate_bandwidth(X, quantile=0.1, n_samples=100)
print(bandwidth)
ms = MeanShift(bandwidth2, bin_seeding=True)
ms.fit(flat_image)
labels=ms.labels_
 
# Plot image vs segmented image
plt.figure(2)
plt.subplot(2, 1, 1)
plt.imshow(image)
plt.axis('off')
plt.subplot(2, 1, 2)
plt.imshow(np.reshape(labels, [851,1280]))
plt.axis('off')
# Out:
# (264, 202)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-1d72f1f6340e> in <module>()
#      20 plt.axis('off')
#      21 plt.subplot(2, 1, 2)
# ---> 22 plt.imshow(np.reshape(labels, [851,1280]))
#      23 plt.axis('off')
#
# /home/serchirag/anaconda2/lib/python2.7/site-packages/numpy/core/fromnumeric.pyc in reshape(a, newshape, order)
#     290            [5, 6]])
#     291     """
# --> 292     return _wrapfunc(a, 'reshape', newshape, order=order)
#     293
#     294
#
# /home/serchirag/anaconda2/lib/python2.7/site-packages/numpy/core/fromnumeric.pyc in _wrapfunc(obj, method, *args, **kwds)
#      54 def _wrapfunc(obj, method, *args, **kwds):
#      55     try:
# ---> 56         return getattr(obj, method)(*args, **kwds)
#      57
#      58     # An AttributeError occurs if the object does not have
#
# ValueError: cannot reshape array of size 17776 into shape (851,1280)
